# %%
import geopandas as geopd
import pandas as pd
import json
import folium

# %%
LODES = pd.read_csv("/home/data/census/nyc/LODES/ny_od_main_JT01_2019.csv")
ntas = geopd.read_file("https://services5.arcgis.com/GfwWNkhOj9bNBqoJ/arcgis/rest/services/NYC_Neighborhood_Tabulation_Areas_2020/FeatureServer/0/query?where=1=1&outFields=*&outSR=4326&f=pgeojson")
crosswalk = pd.read_excel("https://www.nyc.gov/assets/planning/download/office/planning-level/nyc-population/census2020/nyc2020census_tract_nta_cdta_relationships.xlsx?r=092221")

# %%
LODES["w_geocode"] = LODES["w_geocode"].astype(str)
LODES["tract_GEOID_work"] = LODES.w_geocode.str.slice(0,11)

LODES["h_geocode"] = LODES["h_geocode"].astype(str)
LODES["tract_GEOID_res"] = LODES.h_geocode.str.slice(0,11)

# %%
# Summarise at tract level for merge
tract_jobs = LODES.groupby(["tract_GEOID_work", "tract_GEOID_res"]).agg(total_jobs = ("S000", "sum")).reset_index()

# %%
# Adapt crosswalk for easy merge

crosswalk["GEOID"] = crosswalk["GEOID"].astype(str)
crosswalk["tract_GEOID_work"] = crosswalk["GEOID"]
crosswalk["tract_GEOID_res"] = crosswalk["GEOID"]
crosswalk["NTACode_work"] = crosswalk["NTACode"]
crosswalk["NTACode_res"] = crosswalk["NTACode"]

# %%
nta_jobs = (tract_jobs
            .merge(crosswalk[["tract_GEOID_res", "NTACode_res"]])
            .merge(crosswalk[["tract_GEOID_work", "NTACode_work"]])
            .groupby(["NTACode_res", "NTACode_work"])
            .agg(total_jobs = ("total_jobs", "sum"))
           .reset_index())

# %%
def make_job_map(nta_code, nta_jobs, nta_shapes):
    nta = nta_jobs[nta_jobs["NTACode_res"] == nta_code]
    
    map_dat = nta_shapes.merge(nta, right_on = "NTACode_work", left_on = "NTA2020")

    base_map = folium.Map(location=[40.730610, -73.935242], zoom_start=10)

    folium.Choropleth(
        geo_data=map_dat,
        data=map_dat,
        columns=["NTA2020", "total_jobs"],
        key_on="feature.properties.NTA2020",
        fill_color="BuPu",
        fill_opacity=0.7,
        line_opacity=1,
        legend_name="Total Jobs",
        reset=True,
    ).add_to(base_map)
    
    return base_map

# %%
# Out:
#      OBJECTID  BoroCode       BoroName CountyFIPS NTA2020  \
# 0           1         3       Brooklyn        047  BK0101
# 1           2         3       Brooklyn        047  BK0102
# 2           3         3       Brooklyn        047  BK0103
# 3           4         3       Brooklyn        047  BK0104
# 4           5         3       Brooklyn        047  BK0201
# ..        ...       ...            ...        ...     ...
# 257       258         5  Staten Island        085  SI0391
# 258       259         5  Staten Island        085  SI9561
# 259       260         5  Staten Island        085  SI9591
# 260       261         5  Staten Island        085  SI9592
# 261       262         5  Staten Island        085  SI9593
#
#                          NTAName   NTAAbbrev NTAType CDTA2020  \
# 0                     Greenpoint       Grnpt       0     BK01
# 1                   Williamsburg    Wllmsbrg       0     BK01
# 2             South Williamsburg   SWllmsbrg       0     BK01
# 3              East Williamsburg   EWllmsbrg       0     BK01
# 4               Brooklyn Heights       BkHts       0     BK02
# ..                           ...         ...     ...      ...
# 257      Freshkills Park (South)  FrshklPK_S       9     SI03
# 258               Fort Wadsworth   FtWdswrth       6     SI95
# 259  Hoffman & Swinburne Islands    HffmnIsl       9     SI95
# 260                 Miller Field     MllrFld       9     SI95
# 261             Great Kills Park    GrtKlsPk       9     SI95
#
#                                               CDTAName   Shape__Area  \
# 0       BK01 Williamsburg-Greenpoint (CD 1 Equivalent)  3.532193e+07
# 1       BK01 Williamsburg-Greenpoint (CD 1 Equivalent)  2.886227e+07
# 2       BK01 Williamsburg-Greenpoint (CD 1 Equivalent)  1.520934e+07
# 3       BK01 Williamsburg-Greenpoint (CD 1 Equivalent)  5.226618e+07
# 4    BK02 Downtown Brooklyn-Fort Greene (CD 2 Appro...  9.985438e+06
# ..                                                 ...           ...
# 257              SI03 South Shore (CD 3 Approximation)  4.775867e+07
# 258  SI95 Great Kills Park-Fort Wadsworth (JIA 95 A...  9.883809e+06
# 259  SI95 Great Kills Park-Fort Wadsworth (JIA 95 A...  6.357020e+05
# 260  SI95 Great Kills Park-Fort Wadsworth (JIA 95 A...  1.086771e+07
# 261  SI95 Great Kills Park-Fort Wadsworth (JIA 95 A...  2.337356e+07
#
#      Shape__Length                                           geometry
# 0     28914.315199  POLYGON ((-73.93214 40.72817, -73.93253 40.727...
# 1     28155.614512  POLYGON ((-73.95814 40.72441, -73.95772 40.724...
# 2     18252.346181  POLYGON ((-73.95024 40.70548, -73.94984 40.705...
# 3     43184.828736  POLYGON ((-73.92406 40.71412, -73.92404 40.714...
# 4     14337.853843  POLYGON ((-73.99237 40.68970, -73.99436 40.690...
# ..             ...                                                ...
# 257   33945.050028  POLYGON ((-74.20059 40.57952, -74.19888 40.579...
# 258   14852.484590  POLYGON ((-74.05975 40.59386, -74.06014 40.594...
# 259    4743.128127  MULTIPOLYGON (((-74.05314 40.57771, -74.05406 ...
# 260   19196.371774  POLYGON ((-74.08469 40.57149, -74.08595 40.570...
# 261   41497.330515  POLYGON ((-74.11338 40.54808, -74.11341 40.548...
#
# [262 rows x 13 columns]

# %%
make_job_map("QN0704", nta_jobs, ntas)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39e180ba375a0d4e5b49fb4ecad87214 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39e180ba375a0d4e5b49fb4ecad87214&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39e180ba375a0d4e5b49fb4ecad87214 = L.map(
#                 &quot;map_39e180ba375a0d4e5b49fb4ecad87214&quot;,
#                 {
#                     center: [40.73061, -73.935242],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c3644131c71f84dfc7e40c5026335a7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_39e180ba375a0d4e5b49fb4ecad87214);
#
#
#             var choropleth_5ac4ab78f32e26908aed2446bfaaaeb9 = L.featureGroup(
#                 {}
#             ).addTo(map_39e180ba375a0d4e5b49fb4ecad87214);
#
#
#         function geo_json_7c9658c0b17756b1b115d363c3973a91_styler(feature) {
#             switch(feature.id) {
#                 case &quot;97&quot;: case &quot;108&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ebcda&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;109&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#810f7c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;112&quot;: case &quot;113&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bfd3e6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;155&quot;: case &quot;158&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8c96c6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8fb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_7c9658c0b17756b1b115d363c3973a91_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7c9658c0b17756b1b115d363c3973a91 = L.geoJson(null, {
#                 onEachFeature: geo_json_7c9658c0b17756b1b115d363c3973a91_onEachFeature,
#
#                 style: geo_json_7c9658c0b17756b1b115d363c3973a91_styler,
#         });
#
#         function geo_json_7c9658c0b17756b1b115d363c3973a91_add (data) {
#             geo_json_7c9658c0b17756b1b115d363c3973a91
#                 .addData(data)
#                 .addTo(choropleth_5ac4ab78f32e26908aed2446bfaaaeb9);
#         }
#             geo_json_7c9658c0b17756b1b115d363c3973a91_add({&quot;bbox&quot;: [-74.2267247961314, 40.5025412323563, -73.7000104165085, 40.9155410761847], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9623564954015, 40.7184637929789, -73.932135401113, 40.7391362162605], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-73.932135401113, 40.7281678651539], [-73.9325297441291, 40.7278995830578], [-73.9341247994337, 40.7268637331926], [-73.9353988307521, 40.7259151290261], [-73.9367652515319, 40.7248471799857], [-73.9368544957133, 40.7247523602807], [-73.9369503538486, 40.7246613541833], [-73.9370525463333, 40.724574428075], [-73.9371607734565, 40.7244918375201], [-73.9372747154032, 40.7244138245649], [-73.9373940417249, 40.7243406168415], [-73.9375184006835, 40.724272430265], [-73.9376474275425, 40.7242094636342], [-73.9384899983504, 40.7238171667457], [-73.9389132659093, 40.7235870867309], [-73.9393134268226, 40.7233561555043], [-73.9402226643125, 40.7228997665265], [-73.941095616241, 40.7223175064436], [-73.9415052364729, 40.72199923916], [-73.9419577642936, 40.7216605801875], [-73.9428182661973, 40.7211518813537], [-73.943676908702, 40.7206682354436], [-73.944406796295, 40.7202486724442], [-73.9456050187941, 40.719575546151], [-73.9467935461921, 40.718829867662], [-73.9472148483922, 40.7185692459079], [-73.9484178160576, 40.7184637929789], [-73.9485340351111, 40.7191754362495], [-73.9488760272879, 40.7213006661933], [-73.9490795991891, 40.7225485478296], [-73.949867426032, 40.722187744103], [-73.9506473741816, 40.7217139536322], [-73.9516477538682, 40.7234941175687], [-73.9524973801469, 40.7232259941767], [-73.9533218002203, 40.7229409598307], [-73.9538260493936, 40.7227679960343], [-73.9541847359383, 40.7226446884396], [-73.9547780622661, 40.7224677648188], [-73.9562745486831, 40.72339813706], [-73.9577213256299, 40.724293217431], [-73.9581443588599, 40.7244125445028], [-73.958040600857, 40.7244357011626], [-73.9579432689658, 40.7246

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(ntas[["NTA2020", "NTAName"]])
# Out:
#     NTA2020                                            NTAName
# 0    BK0101                                         Greenpoint
# 1    BK0102                                       Williamsburg
# 2    BK0103                                 South Williamsburg
# 3    BK0104                                  East Williamsburg
# 4    BK0201                                   Brooklyn Heights
# 5    BK0202                Downtown Brooklyn-DUMBO-Boerum Hill
# 6    BK0203                                        Fort Greene
# 7    BK0204                                       Clinton Hill
# 8    BK0261                                 Brooklyn Navy Yard
# 9    BK0301                          Bedford-Stuyvesant (West)
# 10   BK0302                          Bedford-Stuyvesant (East)
# 11   BK0401                                    Bushwick (West)
# 12   BK0402                                    Bushwick (East)
# 13   BK0471                            The Evergreens Cemetery
# 14   BK0501                                      Cypress Hills
# 15   BK0502                              East New York (North)
# 16   BK0503                             East New York-New Lots
# 17   BK0504                         Spring Creek-Starrett City
# 18   BK0505                            East New York-City Line
# 19   BK0571     Highland Park-Cypress Hills Cemeteries (South)
# 20   BK0601       Carroll Gardens-Cobble Hill-Gowanus-Red Hook
# 21   BK0602                                         Park Slope
# 22   BK0701                        Windsor Terrace-South Slope
# 23   BK0702                                 Sunset Park (West)
# 24   BK0703                              Sunset Park (Central)
# 25   BK0771                                Green-Wood Cemetery
# 26   BK0801                                   Prospect Heights
# 27   BK0802                              Crown Heights (North)
# 28   BK0891                               Lincoln Terrace Park
# 29   BK0901                              Crown Heights (South)
# 30   BK0902                  Prospect Lefferts Gardens-Wingate
# 31   BK1001                                          Bay Ridge
# 32   BK1002                                      Dyker Heights
# 33   BK1061                                      Fort Hamilton
# 34   BK1091                                   Dyker Beach Park
# 35   BK1101                                        Bensonhurst
# 36   BK1102                                         Bath Beach
# 37   BK1103                                   Gravesend (West)
# 38   BK1201             Sunset Park (East)-Borough Park (West)
# 39   BK1202                                       Borough Park
# 40   BK1203                                         Kensington
# 41   BK1204                            Mapleton-Midwood (West)
# 42   BK1301                                  Gravesend (South)
# 43   BK1302                              Coney Island-Sea Gate
# 44   BK1303                                     Brighton Beach
# 45   BK1391                                  Calvert Vaux Park
# 46   BK1401                                           Flatbush
# 47   BK1402              Flatbush (West)-Ditmas Park-Parkville
# 48   BK1403                                            Midwood
# 49   BK1501                         Gravesend (East)-Homecrest
# 50   BK1502                                            Madison
# 51   BK1503     Sheepshead Bay-Manhattan Beach-Gerritsen Beach
# 52   BK1601                                         Ocean Hill
# 53   BK1602                                        Brownsville
# 54   BK1701                              East Flatbush-Erasmus
# 55   BK1702                             East Flatbush-Farragut
# 56   BK1703                                East Flatbush-Rugby
# 57   BK1704                       East Flatbush-Remsen Village
# 58   BK1771                                Holy Cross Cemetery
# 59   BK1801                                          Flatlands
# 60   BK1802                Marine Park-Mill Basin-Bergen Beach
# 61   BK1803                                           Canarsie
# 62   BK1891                           Marine Park-Plumb Island
# 63   BK1892                                     McGuire Fields
# 64   BK1893                               Canarsie Park & Pier
# 65   BK5591                                      Prospect Park
# 66   BK5691                  Barren Island-Floyd Bennett Field
# 67   BK5692                                 Jamaica Bay (West)
# 68   BK5693                        Shirley Chisholm State Park
# 69   BX0101                             Mott Haven-Port Morris
# 70   BX0102                                            Melrose
# 71   BX0201                                        Hunts Point
# 72   BX0202                                           Longwood
# 73   BX0291                      North & South Brother Islands
# 74   BX0301                                         Morrisania
# 75   BX0302                 Claremont Village-Claremont (East)
# 76   BX0303                                  Crotona Park East
# 77   BX0391                                       Crotona Park
# 78   BX0401                        Concourse-Concourse Village
# 79   BX0402                                         Highbridge
# 80   BX0403                        Mount Eden-Claremont (West)
# 81   BX0491                    Yankee Stadium-Macombs Dam Park
# 82   BX0492                                     Claremont Park
# 83   BX0501          University Heights (South)-Morris Heights
# 84   BX0502                                         Mount Hope
# 85   BX0503                                    Fordham Heights
# 86   BX0601                                         West Farms
# 87   BX0602                                            Tremont
# 88   BX0603                                            Belmont
# 89   BX0701                 University Heights (North)-Fordham
# 90   BX0702                                       Bedford Park
# 91   BX0703                                            Norwood
# 92   BX0801          Kingsbridge Heights-Van Cortlandt Village
# 93   BX0802                            Kingsbridge-Marble Hill
# 94   BX0803                           Riverdale-Spuyten Duyvil
# 95   BX0901                     Soundview-Bruckner-Bronx River
# 96   BX0902                             Soundview-Clason Point
# 97   BX0903                              Castle Hill-Unionport
# 98   BX0904                                        Parkchester
# 99   BX0991                                     Soundview Park
# 100  BX1001                                 Westchester Square
# 101  BX1002                          Throgs Neck-Schuylerville
# 102  BX1003                Pelham Bay-Country Club-City Island
# 103  BX1004                                         Co-op City
# 104  BX1071                                        Hart Island
# 105  BX1091              Ferry Point Park-St. Raymond Cemetery
# 106  BX1101                            Pelham Parkway-Van Nest
# 107  BX1102                                        Morris Park
# 108  BX1103                                     Pelham Gardens
# 109  BX1104                                           Allerton
# 110  BX1161                            Hutchinson Metro Center
# 111  BX1201                           Williamsbridge-Olinville
# 112  BX1202                    Eastchester-Edenwald-Baychester
# 113  BX1203                                 Wakefield-Woodlawn
# 114  BX1271                                  Woodlawn Cemetery
# 115  BX2691                                 Van Cortlandt Park
# 116  BX2791                                         Bronx Park
# 117  BX2891                                    Pelham Bay Park
# 118  MN0101               Financial District-Battery Park City
# 119  MN0102                               Tribeca-Civic Center
# 120  MN0191  The Battery-Governors Island-Ellis Island-Libe...
# 121  MN0201                    SoHo-Little Italy-Hudson Square
# 122  MN0202                                  Greenwich Village
# 123  MN0203                                       West Village
# 124  MN0301                              Chinatown-Two Bridges
# 125  MN0302                                    Lower East Side
# 126  MN0303                                       East Village
# 127  MN0401                               Chelsea-Hudson Yards
# 128  MN0402                                     Hell's Kitchen
# 129  MN0501                Midtown South-Flatiron-Union Square
# 130  MN0502                               Midtown-Times Square
# 131  MN0601               Stuyvesant Town-Peter Cooper Village
# 132  MN0602                                           Gramercy
# 133  MN0603                               Murray Hill-Kips Bay
# 134  MN0604                            East Midtown-Turtle Bay
# 135  MN0661                                     United Nations
# 136  MN0701                     Upper West Side-Lincoln Square
# 137  MN0702                          Upper West Side (Central)
# 138  MN0703                   Upper West Side-Manhattan Valley
# 139  MN0801        Upper East Side-Lenox Hill-Roosevelt Island
# 140  MN0802                      Upper East Side-Carnegie Hill
# 141  MN0803                          Upper East Side-Yorkville
# 142  MN0901                                Morningside Heights
# 143  MN0902                         Manhattanville-West Harlem
# 144  MN0903                        Hamilton Heights-Sugar Hill
# 145  MN1001                                     Harlem (South)
# 146  MN1002                                     Harlem (North)
# 147  MN1101                                East Harlem (South)
# 148  MN1102                                East Harlem (North)
# 149  MN1191                                   Randall's Island
# 150  MN1201                         Washington Heights (South)
# 151  MN1202                         Washington Heights (North)
# 152  MN1203                                             Inwood
# 153  MN1291                                    Highbridge Park
# 154  MN1292                                   Inwood Hill Park
# 155  MN6491                                       Central Park
# 156  QN0101                   Astoria (North)-Ditmars-Steinway
# 157  QN0102                          Old Astoria-Hallets Point
# 158  QN0103                                  Astoria (Central)
# 159  QN0104                    Astoria (East)-Woodside (North)
# 160  QN0105                Queensbridge-Ravenswood-Dutch Kills
# 161  QN0151                                      Rikers Island
# 162  QN0161                            Sunnyside Yards (North)
# 163  QN0171                             St. Michael's Cemetery
# 164  QN0191                                       Astoria Park
# 165  QN0201                     Long Island City-Hunters Point
# 166  QN0202                                          Sunnyside
# 167  QN0203                                           Woodside
# 168  QN0261                            Sunnyside Yards (South)
# 169  QN0271                    Calvary & Mount Zion Cemeteries
# 170  QN0301                                    Jackson Heights
# 171  QN0302                                      East Elmhurst
# 172  QN0303                                       North Corona
# 173  QN0401                                           Elmhurst
# 174  QN0402                                             Corona
# 175  QN0501                                            Maspeth
# 176  QN0502                                          Ridgewood
# 177  QN0503                                           Glendale
# 178  QN0504                                     Middle Village
# 179  QN0571               Mount Olivet & All Faiths Cemeteries
# 180  QN0572                            Middle Village Cemetery
# 181  QN0573                                  St. John Cemetery
# 182  QN0574     Highland Park-Cypress Hills Cemeteries (North)
# 183  QN0601                                          Rego Park
# 184  QN0602                                       Forest Hills
# 185  QN0701                                      College Point
# 186  QN0702                              Whitestone-Beechhurst
# 187  QN0703                              Bay Terrace-Clearview
# 188  QN0704                      Murray Hill-Broadway Flushing
# 189  QN0705                                      East Flushing
# 190  QN0706                                    Queensboro Hill
# 191  QN0707                             Flushing-Willets Point
# 192  QN0761                                        Fort Totten
# 193  QN0791                                       Kissena Park
# 194  QN0801                                  Kew Gardens Hills
# 195  QN0802                     Pomonok-Electchester-Hillcrest
# 196  QN0803                               Fresh Meadows-Utopia
# 197  QN0804                         Jamaica Estates-Holliswood
# 198  QN0805                            Jamaica Hills-Briarwood
# 199  QN0871              Mount Hebron & Cedar Grove Cemeteries
# 200  QN0891                                    Cunningham Park
# 201  QN0901                                        Kew Gardens
# 202  QN0902                                      Richmond Hill
# 203  QN0903                                South Richmond Hill
# 204  QN0904                                 Ozone Park (North)
# 205  QN0905                                          Woodhaven
# 206  QN1001                                   South Ozone Park
# 207  QN1002                                         Ozone Park
# 208  QN1003                            Howard Beach-Lindenwood
# 209  QN1091                                  Spring Creek Park
# 210  QN1101                                         Auburndale
# 211  QN1102                                            Bayside
# 212  QN1103                             Douglaston-Little Neck
# 213  QN1104                       Oakland Gardens-Hollis Hills
# 214  QN1191                                    Alley Pond Park
# 215  QN1201                                            Jamaica
# 216  QN1202                                      South Jamaica
# 217  QN1203                                       Baisley Park
# 218  QN1204       Springfield Gardens (North)-Rochdale Village
# 219  QN1205                                         St. Albans
# 220  QN1206                                             Hollis
# 221  QN1301                Glen Oaks-Floral Park-New Hyde Park
# 222  QN1302                                          Bellerose
# 223  QN1303                                     Queens Village
# 224  QN1304                                    Cambria Heights
# 225  QN1305                                          Laurelton
# 226  QN1306             Springfield Gardens (South)-Brookville
# 227  QN1307                                           Rosedale
# 228  QN1371                                Montefiore Cemetery
# 229  QN1401                             Far Rockaway-Bayswater
# 230  QN1402                    Rockaway Beach-Arverne-Edgemere
# 231  QN1403  Breezy Point-Belle Harbor-Rockaway Park-Broad ...
# 232  QN1491                            Rockaway Community Park
# 233  QN8081                                  LaGuardia Airport
# 234  QN8191                       Flushing Meadows-Corona Park
# 235  QN8291                                        Forest Park
# 236  QN8381              John F. Kennedy International Airport
# 237  QN8491                                 Jamaica Bay (East)
# 238  QN8492       Jacob Riis Park-Fort Tilden-Breezy Point Tip
# 239  SI0101                            St. George-New Brighton
# 240  SI0102          Tompkinsville-Stapleton-Clifton-Fox Hills
# 241  SI0103                     Rosebank-Shore Acres-Park Hill
# 242  SI0104          West New Brighton-Silver Lake-Grymes Hill
# 243  SI0105                      Westerleigh-Castleton Corners
# 244  SI0106                                      Port Richmond
# 245  SI0107            Mariner's Harbor-Arlington-Graniteville
# 246  SI0191                                        Snug Harbor
# 247  SI0201         Grasmere-Arrochar-South Beach-Dongan Hills
# 248  SI0202                             New Dorp-Midland Beach
# 249  SI0203  Todt Hill-Emerson Hill-Lighthouse Hill-Manor H...
# 250  SI0204      New Springville-Willowbrook-Bulls Head-Travis
# 251  SI0291                            Freshkills Park (North)
# 252  SI0301                               Oakwood-Richmondtown
# 253  SI0302                            Great Kills-Eltingville
# 254  SI0303                            Arden Heights-Rossville
# 255  SI0304             Annadale-Huguenot-Prince's Bay-Woodrow
# 256  SI0305                             Tottenville-Charleston
# 257  SI0391                            Freshkills Park (South)
# 258  SI9561                                     Fort Wadsworth
# 259  SI9591                        Hoffman & Swinburne Islands
# 260  SI9592                                       Miller Field
# 261  SI9593                                   Great Kills Park

# %%
ntas
# Out:
#      OBJECTID  BoroCode       BoroName CountyFIPS NTA2020  \
# 0           1         3       Brooklyn        047  BK0101
# 1           2         3       Brooklyn        047  BK0102
# 2           3         3       Brooklyn        047  BK0103
# 3           4         3       Brooklyn        047  BK0104
# 4           5         3       Brooklyn        047  BK0201
# ..        ...       ...            ...        ...     ...
# 257       258         5  Staten Island        085  SI0391
# 258       259         5  Staten Island        085  SI9561
# 259       260         5  Staten Island        085  SI9591
# 260       261         5  Staten Island        085  SI9592
# 261       262         5  Staten Island        085  SI9593
#
#                          NTAName   NTAAbbrev NTAType CDTA2020  \
# 0                     Greenpoint       Grnpt       0     BK01
# 1                   Williamsburg    Wllmsbrg       0     BK01
# 2             South Williamsburg   SWllmsbrg       0     BK01
# 3              East Williamsburg   EWllmsbrg       0     BK01
# 4               Brooklyn Heights       BkHts       0     BK02
# ..                           ...         ...     ...      ...
# 257      Freshkills Park (South)  FrshklPK_S       9     SI03
# 258               Fort Wadsworth   FtWdswrth       6     SI95
# 259  Hoffman & Swinburne Islands    HffmnIsl       9     SI95
# 260                 Miller Field     MllrFld       9     SI95
# 261             Great Kills Park    GrtKlsPk       9     SI95
#
#                                               CDTAName   Shape__Area  \
# 0       BK01 Williamsburg-Greenpoint (CD 1 Equivalent)  3.532193e+07
# 1       BK01 Williamsburg-Greenpoint (CD 1 Equivalent)  2.886227e+07
# 2       BK01 Williamsburg-Greenpoint (CD 1 Equivalent)  1.520934e+07
# 3       BK01 Williamsburg-Greenpoint (CD 1 Equivalent)  5.226618e+07
# 4    BK02 Downtown Brooklyn-Fort Greene (CD 2 Appro...  9.985438e+06
# ..                                                 ...           ...
# 257              SI03 South Shore (CD 3 Approximation)  4.775867e+07
# 258  SI95 Great Kills Park-Fort Wadsworth (JIA 95 A...  9.883809e+06
# 259  SI95 Great Kills Park-Fort Wadsworth (JIA 95 A...  6.357020e+05
# 260  SI95 Great Kills Park-Fort Wadsworth (JIA 95 A...  1.086771e+07
# 261  SI95 Great Kills Park-Fort Wadsworth (JIA 95 A...  2.337356e+07
#
#      Shape__Length                                           geometry
# 0     28914.315199  POLYGON ((-73.93214 40.72817, -73.93253 40.727...
# 1     28155.614512  POLYGON ((-73.95814 40.72441, -73.95772 40.724...
# 2     18252.346181  POLYGON ((-73.95024 40.70548, -73.94984 40.705...
# 3     43184.828736  POLYGON ((-73.92406 40.71412, -73.92404 40.714...
# 4     14337.853843  POLYGON ((-73.99237 40.68970, -73.99436 40.690...
# ..             ...                                                ...
# 257   33945.050028  POLYGON ((-74.20059 40.57952, -74.19888 40.579...
# 258   14852.484590  POLYGON ((-74.05975 40.59386, -74.06014 40.594...
# 259    4743.128127  MULTIPOLYGON (((-74.05314 40.57771, -74.05406 ...
# 260   19196.371774  POLYGON ((-74.08469 40.57149, -74.08595 40.570...
# 261   41497.330515  POLYGON ((-74.11338 40.54808, -74.11341 40.548...
#
# [262 rows x 13 columns]
